# %%
import numpy as np
import matplotlib

t_array = np.load("t_distribution_tensor.npy")

# %%
import matplotlib.pyplot as plt

plt.hist(t_array.flatten(), bins=50, density=True, alpha=0.7)
plt.title("Distribution de t_array")
plt.xlabel("Valeur")
plt.ylabel("Densité")
plt.show()
