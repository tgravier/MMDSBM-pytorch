# %%
import numpy as np

mean = np.array([0.0, 0.0])
std = np.array([1.0, 1.0])
n = 1000
dim = 2

data = np.random.normal(loc=mean, scale=std, size=(n, dim))
print(data.shape)  # Devrait afficher (1000, 2)
# Out:
# (1000, 2)
