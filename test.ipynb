# %%
import numpy as np

# %%
test = np.load("test.npy")

# %%
test.shape
# Out:
# (1000, 2, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(test[:, 1, 0], test[:, 1, 1], alpha=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Distribution 1')
plt.axis('equal')
plt.show()

# %%
test[:,0,:].T
# Out:
# array([[-2.660906 , -2.4062433, -2.1482978, ..., -2.8319263, -3.4464564,
#         -2.0614917],
#        [-1.0253671, -1.0247693,  3.8327415, ...,  3.3861563,  3.7022195,
#          2.9272325]], shape=(2, 1000), dtype=float32)
